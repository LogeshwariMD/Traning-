# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
file_path = "lex.csv"
df = pd.read_csv(file_path)
df
# Out:
#           country  1800  1801  1802  1803  1804  1805  1806  1807  1808  ...  \
# 0     Afghanistan  28.2  28.2  28.2  28.2  28.2  28.2  28.1  28.1  28.1  ...
# 1          Angola  27.0  27.0  27.0  27.0  27.0  27.0  27.0  27.0  27.0  ...
# 2         Albania  35.4  35.4  35.4  35.4  35.4  35.4  35.4  35.4  35.4  ...
# 3         Andorra   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 4             UAE  30.7  30.7  30.7  30.7  30.7  30.7  30.7  30.7  30.7  ...
# ..            ...   ...   ...   ...   ...   ...   ...   ...   ...   ...  ...
# 191         Samoa  25.4  25.4  25.4  25.4  25.4  25.4  25.4  25.4  25.4  ...
# 192         Yemen  23.4  23.4  23.4  23.4  23.4  23.4  23.4  23.4  23.4  ...
# 193  South Africa  33.5  33.5  33.5  33.5  33.5  33.5  33.5  33.5  33.5  ...
# 194        Zambia  32.6  32.6  32.6  32.6  32.6  32.6  32.6  32.6  32.6  ...
# 195      Zimbabwe  33.7  33.7  33.7  33.7  33.7  33.7  33.7  33.7  33.7  ...
#
# ...

# %%
print("Column Names:", df.columns)
# Out:
# Column Names: Index(['country', '1800', '1801', '1802', '1803', '1804', '1805', '1806',
#        '1807', '1808',
#        ...
#        '2091', '2092', '2093', '2094', '2095', '2096', '2097', '2098', '2099',
#        '2100'],
#       dtype='object', length=302)

# %%
df_long = df.melt(id_vars=['country'], var_name='Year', value_name='Life_Expectancy')

# %%
df_long['Year'] = pd.to_numeric(df_long['Year'], errors='coerce')
df_long['Life_Expectancy'] = pd.to_numeric(df_long['Life_Expectancy'], errors='coerce')

# %%
df_long.dropna(inplace=True)

# %%
plt.figure(figsize=(12, 6))
plt.plot(avg_life['Year'], avg_life['Life_Expectancy'], color='blue', linewidth=2)
plt.title('Average Life Expectancy Over Years', fontsize=16)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Average Life Expectancy', fontsize=14)
plt.grid(True)
plt.tight_layout()
plt.show()
