# %% [markdown]
# Task 1: Scrape Cricket Series

# %%
# !pip install selenium pandas beautifulsoup4
# Out:
# Requirement already satisfied: selenium in c:\users\loges\appdata\roaming\python\python312\site-packages (4.29.0)
# Requirement already satisfied: pandas in c:\users\loges\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\loges\anaconda3\lib\site-packages (4.12.3)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\loges\anaconda3\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (2.2.2)
# Requirement already satisfied: trio~=0.17 in c:\users\loges\appdata\roaming\python\python312\site-packages (from selenium) (0.29.0)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\loges\appdata\roaming\python\python312\site-packages (from selenium) (0.12.1)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\loges\anaconda3\lib\site-packages (from selenium) (2024.6.2)
# Requirement already satisfied: typing_extensions~=4.9 in c:\users\loges\appdata\roaming\python\python312\site-packages (from selenium) (4.12.2)
# Requirement already satisfied: websocket-client~=1.8 in c:\users\loges\anaconda3\lib\site-packages (from selenium) (1.8.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\loges\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\loges\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\loges\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\loges\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\loges\anaconda3\lib\site-packages (from beautifulsoup4) (2.5)
# Requirement already satisfied: six>=1.5 in c:\users\loges\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: attrs>=23.2.0 in c:\users\loges\appdata\roaming\python\python312\site-packages (from trio~=0.17->selenium) (25.1.0)
# Requirement already satisfied: sortedcontainers in c:\users\loges\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in c:\users\loges\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.7)
# Requirement already satisfied: outcome in c:\users\loges\appdata\roaming\python\python312\site-packages (from trio~=0.17->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in c:\users\loges\appdata\roaming\python\python312\site-packages (from trio~=0.17->selenium) (1.3.1)
# Requirement already satisfied: cffi>=1.14 in c:\users\loges\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.16.0)
# Requirement already satisfied: wsproto>=0.14 in c:\users\loges\appdata\roaming\python\python312\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in c:\users\loges\anaconda3\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\loges\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\loges\appdata\roaming\python\python312\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
import time

# %%
options = Options()
options.add_argument("--start-maximized")
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)


url = 'https://www.cricbuzz.com/cricket-scorecard-archives'
driver.get(url)


time.sleep(3)


last_height = driver.execute_script("return document.body.scrollHeight")
while True:
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(2)
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height


data = []


series_containers = driver.find_elements(By.CSS_SELECTOR, 'div.cb-col.cb-col-100.cb-bg-white')

print(f"Found {len(series_containers)} series containers.")

for container in series_containers:
    try:
        
        year_element = container.find_element(By.TAG_NAME, 'h2')
        year = year_element.text.strip()

    
        series_links = container.find_elements(By.TAG_NAME, 'a')

        for link in series_links:
            series_name = link.text.strip()
            series_href = link.get_attribute('href')

            # Store the data
            data.append({
                'year': year,
                'series_name': series_name,
                'series_href': "https://www.cricbuzz.com" + series_href
            })

    except Exception as e:
        print(f"Error processing container: {e}")


df = pd.DataFrame(data)


print(df.head())


df.to_csv('cricbuzz_series.csv', index=False)

print("Data saved successfully!")


driver.quit()
# Out:
# Found 2 series containers.
# Error processing container: Message: no such element: Unable to locate element: {"method":"tag name","selector":"h2"}
#   (Session info: chrome=135.0.7049.42); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00545413+60691]
# 	GetHandleVerifier [0x00545454+60756]
# 	(No symbol) [0x00370693]
# 	(No symbol) [0x003B8660]
# 	(No symbol) [0x003B89FB]
# 	(No symbol) [0x003ADDA1]
# 	(No symbol) [0x003DD0A4]
# 	(No symbol) [0x003ADCC4]
# 	(No symbol) [0x003DD2D4]
# 	(No symbol) [0x003FE6FB]
# 	(No symbol) [0x003DCE56]
# 	(No symbol) [0x003AC5F3]
# 	(No symbol) [0x003AD444]
# 	GetHandleVerifier [0x0078BBC3+2446531]
# 	GetHandleVerifier [0x00787198+2427544]
# 	GetHandleVerifier [0x007A2D5E+2541150]
# 	GetHandleVerifier [0x0055C3C5+154821]
# 	GetHandleVerifier [0x00562BED+181485]
# 	GetHandleVerifier [0x0054CC48+91464]
# 	GetHandleVerifier [0x0054CDF0+91888]
# 	GetHandleVerifier [0x00537980+4736]
# 	BaseThreadInitThunk [0x75E35D49+25]
# 	RtlInitializeExceptionChain [0x7736CE3B+107]
# 	RtlGetAppContainerNamedObjectPath [0x7736CDC1+561]
#
#    year                               series_name  \
# 0  2025              Canada tour of Namibia, 2025
# 1  2025        Pakistan tour of New Zealand, 2025
# 2  2025  Falkland Islands tour of Costa Rica 2025
# 3  2025     Malaysia Tri-Nation T20I Series, 2025
# 4  2025           Bahrain tour of Singapore, 2025
#
#                                          series_href
# 0  https://www.cricbuzz.comhttps://www.cricbuzz.c...
# 1  https://www.cricbuzz.comhttps://www.cricbuzz.c...
# 2  https://www.cricbuzz.comhttps://www.cricbuzz.c...
# 3  https://www.cricbuzz.comhttps://www.cricbuzz.c...
# 4  https://www.cricbuzz.comhttps://www.cricbuzz.c...
# Data saved successfully!
